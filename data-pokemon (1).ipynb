# %% [markdown]
# # POKEMON     guatri gabriele/caiola luca/ mesisca giovanni

# %%
import pandas as pd
df = pd.read_csv("pokemons.csv")

# %%
df
# Out:
#         id         name       rank     generation  evolves_from   type1  \
# 0        1    bulbasaur   ordinary   generation-i       nothing   grass
# 1        2      ivysaur   ordinary   generation-i     bulbasaur   grass
# 2        3     venusaur   ordinary   generation-i       ivysaur   grass
# 3        4   charmander   ordinary   generation-i       nothing    fire
# 4        5   charmeleon   ordinary   generation-i    charmander    fire
# ...    ...          ...        ...            ...           ...     ...
# 1012  1013    sinistcha   ordinary  generation-ix  poltchageist   grass
# 1013  1014      okidogi  legendary  generation-ix       nothing  poison
# 1014  1015    munkidori  legendary  generation-ix       nothing  poison
# 1015  1016  fezandipiti  legendary  generation-ix       nothing  poison
# 1016  1017      ogerpon  legendary  generation-ix       nothing   grass
#
#          type2  hp  atk  def  spatk  spdef  speed  total  height  weight  \
# ...

# %%
df.shape
# Out:
# (1017, 18)

# %%
df.isnull()
# Out:
#          id   name   rank  generation  evolves_from  type1  type2     hp  \
# 0     False  False  False       False         False  False  False  False
# 1     False  False  False       False         False  False  False  False
# 2     False  False  False       False         False  False  False  False
# 3     False  False  False       False         False  False  False  False
# 4     False  False  False       False         False  False  False  False
# ...     ...    ...    ...         ...           ...    ...    ...    ...
# 1012  False  False  False       False         False  False  False  False
# 1013  False  False  False       False         False  False  False  False
# 1014  False  False  False       False         False  False  False  False
# 1015  False  False  False       False         False  False  False  False
# 1016  False  False  False       False         False  False  False  False
#
#         atk    def  spatk  spdef  speed  total  height  weight  abilities  \
# ...

# %%
df.isnull().sum()
# Out:
# id              0
# name            0
# rank            0
# generation      0
# evolves_from    0
# type1           0
# type2           0
# hp              0
# atk             0
# def             0
# spatk           0
# spdef           0
# speed           0
# total           0
# height          0
# weight          0
# abilities       0
# desc            0
# dtype: int64

# %%
 percentage_missing = df.isnull().sum() * 100 / len(df)
print(percentage_missing)
# Out:
# id              0.0
# name            0.0
# rank            0.0
# generation      0.0
# evolves_from    0.0
# type1           0.0
# type2           0.0
# hp              0.0
# atk             0.0
# def             0.0
# spatk           0.0
# spdef           0.0
# speed           0.0
# total           0.0
# height          0.0
# weight          0.0
# abilities       0.0
# desc            0.0
# dtype: float64

# %%
df1 = df.fillna(method = 'bfill')
df1
# Out:
#         id         name       rank     generation  evolves_from   type1  \
# 0        1    bulbasaur   ordinary   generation-i       nothing   grass
# 1        2      ivysaur   ordinary   generation-i     bulbasaur   grass
# 2        3     venusaur   ordinary   generation-i       ivysaur   grass
# 3        4   charmander   ordinary   generation-i       nothing    fire
# 4        5   charmeleon   ordinary   generation-i    charmander    fire
# ...    ...          ...        ...            ...           ...     ...
# 1012  1013    sinistcha   ordinary  generation-ix  poltchageist   grass
# 1013  1014      okidogi  legendary  generation-ix       nothing  poison
# 1014  1015    munkidori  legendary  generation-ix       nothing  poison
# 1015  1016  fezandipiti  legendary  generation-ix       nothing  poison
# 1016  1017      ogerpon  legendary  generation-ix       nothing   grass
#
#          type2   hp  atk  def  spatk  spdef  speed  total  height  weight  \
# ...

# %%
df2 = df.fillna(method = 'bfill')
df2
# Out:
#         id         name       rank     generation  evolves_from   type1  \
# 0        1    bulbasaur   ordinary   generation-i       nothing   grass
# 1        2      ivysaur   ordinary   generation-i     bulbasaur   grass
# 2        3     venusaur   ordinary   generation-i       ivysaur   grass
# 3        4   charmander   ordinary   generation-i       nothing    fire
# 4        5   charmeleon   ordinary   generation-i    charmander    fire
# ...    ...          ...        ...            ...           ...     ...
# 1012  1013    sinistcha   ordinary  generation-ix  poltchageist   grass
# 1013  1014      okidogi  legendary  generation-ix       nothing  poison
# 1014  1015    munkidori  legendary  generation-ix       nothing  poison
# 1015  1016  fezandipiti  legendary  generation-ix       nothing  poison
# 1016  1017      ogerpon  legendary  generation-ix       nothing   grass
#
#          type2  hp  atk  def  spatk  spdef  speed  total  height  weight  \
# ...

# %%
mean_value = df['total'].mean()
std_dev = df['total'].std()
std_dev
# Out:
# 112.43249151550005

# %%
outliers = df[(df['total'] > mean_value + 3 * std_dev) | (df['total'] < mean_value - 3 * std_dev)]
outliers
# Out:
# Empty DataFrame
# Columns: [id, name, rank, generation, evolves_from, type1, type2, hp, atk, def, spatk, spdef, speed, total, height, weight, abilities, desc]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pokemon_data = pd.read_csv('C:\\Users\\utente\\Pokemons.csv')

mean_value = pokemon_data['total'].mean()
std_dev = pokemon_data['total'].std()
outliers = pokemon_data[(pokemon_data['hp'] > mean_value + 3 * std_dev) | (pokemon_data['hp'] < mean_value - 3 * std_dev)]
plt.scatter(pokemon_data.index, pokemon_data['total'], label='total')
plt.scatter(outliers.index, outliers['total'], color='red', label='Outliers')


plt.axhline(y=mean_value, color='green', linestyle='--', label='Media')
plt.axhline(y=mean_value + 3 * std_dev, color='orange', linestyle='--', label='±3 Deviazioni Standard')
plt.axhline(y=mean_value - 3 * std_dev, color='orange', linestyle='--')

plt.xlabel('Indice')
plt.title('Grafico che evidenzia')
plt.legend()
plt.show()

# %%
plt.scatter(outliers.index, outliers['total'], color='blue', label='Outliers')
plt.axhline(y=mean_value, color='green', linestyle='-', label='Media')
plt.axhline(y=mean_value + 3 * std_dev, color='orange', linestyle='-', label='±3 Deviazioni Standard')
plt.axhline(y=mean_value - 3 * std_dev, color='orange', linestyle='-')

plt.xlabel('Indice')
plt.ylabel('punti totali')
plt.title('Outliers dei punti totali')
plt.legend()
plt.show()

# %%
df.dtypes
# Out:
# id               int64
# name            object
# rank            object
# generation      object
# evolves_from    object
# type1           object
# type2           object
# hp               int64
# atk              int64
# def              int64
# spatk            int64
# spdef            int64
# speed            int64
# total            int64
# height           int64
# weight           int64
# abilities       object
# desc            object
# dtype: object

# %%
x = df.iloc[:,[7,8,9]]

# %%
x
# Out:
#        hp  atk  def
# 0      49   49   49
# 1      62   62   63
# 2      82   82   83
# 3      52   52   43
# 4      64   64   58
# ...   ...  ...  ...
# 1012   60   60  106
# 1013  128  128  115
# 1014   75   75   66
# 1015   91   91   82
# 1016  120  120   84
#
# [1017 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

print("DataFrame prima dello scaling:")
print(x)

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(x)

scaled_x = pd.DataFrame(scaled_data, columns=x.columns) # Creiamo un nuovo DataFrame con le features scalate

print("\nDataFrame dopo lo scaling:") # Visualizziamo il DataFrame dopo lo scaling
print(scaled_x)
# Out:
# DataFrame prima dello scaling:
#        hp  atk  def
# 0      49   49   49
# 1      62   62   63
# 2      82   82   83
# 3      52   52   43
# 4      64   64   58
# ...   ...  ...  ...
# 1012   60   60  106
# 1013  128  128  115
# 1014   75   75   66
# 1015   91   91   82
# 1016  120  120   84
#
# [1017 rows x 3 columns]
#
# DataFrame dopo lo scaling:
#             hp       atk       def
# 0     0.250000  0.250000  0.195556
# 1     0.323864  0.323864  0.257778
# 2     0.437500  0.437500  0.346667
# 3     0.267045  0.267045  0.168889
# 4     0.335227  0.335227  0.235556
# ...        ...       ...       ...
# 1012  0.312500  0.312500  0.448889
# 1013  0.698864  0.698864  0.488889
# 1014  0.397727  0.397727  0.271111
# 1015  0.488636  0.488636  0.342222
# 1016  0.653409  0.653409  0.351111
#
# [1017 rows x 3 columns]

# %%
import pandas as pd

pokemon_data = pd.read_csv('pokemons.csv')
print(pokemon_data.head())
# Out:
#    id        name      rank    generation evolves_from  type1   type2  hp  \
# 0   1   bulbasaur  ordinary  generation-i      nothing  grass  poison  45
# 1   2     ivysaur  ordinary  generation-i    bulbasaur  grass  poison  60
# 2   3    venusaur  ordinary  generation-i      ivysaur  grass  poison  80
# 3   4  charmander  ordinary  generation-i      nothing   fire    None  39
# 4   5  charmeleon  ordinary  generation-i   charmander   fire    None  58
#
#    atk  def  spatk  spdef  speed  total  height  weight  \
# 0   49   49     65     65     45    318       7      69
# 1   62   63     80     80     60    405      10     130
# 2   82   83    100    100     80    525      20    1000
# 3   52   43     60     50     65    309       6      85
# 4   64   58     80     65     80    405      11     190
#
#                abilities                                               desc
# 0  overgrow chlorophyll   A strange seed was planted on its back at birt...
# ...

# %%
# ordinale scaler
import pandas as pd

pokemon_data = pd.read_csv('pokemons.csv')

tipi_pokemon = pokemon_data['type1'].unique()
tipi_pokemon = pokemon_data['type2'].unique()

ordine_tipi = {tipo: i+1 for i, tipo in enumerate(tipi_pokemon)}

data = {'Tipo': ['water', 'fire', 'grass']}
df = pd.DataFrame(data)

df['Tipo_Ordinale'] = df['Tipo'].map(ordine_tipi)

print(df)
# Out:
#     Tipo  Tipo_Ordinale
# 0  water             12
# 1   fire             14
# 2  grass              6
